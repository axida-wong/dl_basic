# %%
import os
import pandas as pd 
import torch

os.makedirs(os.path.join('.', 'data'), exist_ok=True)
data_file = os.path.join('.', 'data', 'house_tiny.csv')
with open(data_file, 'w') as f:
    f.write('NumRooms,Alley,Price\n') # 列名
    f.write('NA,Pave,127500\n') # 每行表示一个数据样本
    f.write('2,NA,106000\n') 
    f.write('4,NA,178100\n') 
    f.write('NA,NA,140000\n')

# %%
data = pd.read_csv(data_file, na_values=['NA'])
print(data)
print(data.dtypes)
print(data.isna())
# Out:
#    NumRooms Alley   Price
# 0       NaN  Pave  127500
# 1       2.0   NaN  106000
# 2       4.0   NaN  178100
# 3       NaN   NaN  140000
# NumRooms    float64
# Alley           str
# Price         int64
# dtype: object
#    NumRooms  Alley  Price
# 0      True  False  False
# 1     False   True  False
# 2     False   True  False
# 3      True   True  False

# %%
# 位置索引，iloc, 将data分成inputs和outputs
inputs, outputs = data.iloc[:, 0:2], data.iloc[:, 2]
inputs = inputs.fillna(inputs.mean(numeric_only=True)) #fill NAs with the argument 
# numeric_only 只计算数字的平均
print(inputs)
# Out:
#    NumRooms Alley
# 0       3.0  Pave
# 1       2.0   NaN
# 2       4.0   NaN
# 3       3.0   NaN

# %%
inputs = pd.get_dummies(inputs, dummy_na=True)
inputs = inputs.astype('float32')
inputs
# Out:
#    NumRooms  Alley_Pave  Alley_nan
# 0       3.0         1.0        0.0
# 1       2.0         0.0        1.0
# 2       4.0         0.0        1.0
# 3       3.0         0.0        1.0

# %%
# convert to tensor structrue

X, y =  torch.tensor(inputs.values), torch.tensor(outputs.values)
X, y
# Out:
# (tensor([[3., 1., 0.],
#          [2., 0., 1.],
#          [4., 0., 1.],
#          [3., 0., 1.]]),
#  tensor([127500, 106000, 178100, 140000]))
